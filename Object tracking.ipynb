# %%
import cv2
from ultralytics import YOLO
import numpy as np

model = YOLO('yolov8n.pt')  

cam = cv2.VideoCapture(0)

ret, first_frame = cam.read()

bbox = cv2.selectROI("Select Object", first_frame, fromCenter=False, showCrosshair=True)
cv2.destroyAllWindows()

(x, y, w, h) = map(int, bbox)
selected_box = [x, y, x + w, y + h]  # Convert to (x1, y1, x2, y2)

initial_result = model.predict(source=first_frame, conf=0.3)[0]
selected_class = None

def compute_iou(boxA, boxB):
    # Compute intersection over union
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    interArea = max(0, xB - xA) * max(0, yB - yA)
    if interArea == 0:
        return 0.0

    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

best_iou = 0
for box in initial_result.boxes:
    detected_box = box.xyxy[0].cpu().numpy().astype(int)
    iou = compute_iou(detected_box, selected_box)
    if iou > best_iou:
        best_iou = iou
        selected_class = int(box.cls[0])

if selected_class is None:
    print("Couldn't detect any object inside the selected box.")
    exit()

print(f"Tracking class: {model.names[selected_class]}")

while True:
    ret, frame = cam.read()
    if not ret:
        break

    results = model.predict(source=frame, conf=0.3, stream=True)

    for result in results:
        for box in result.boxes:
            cls_id = int(box.cls[0])
            if cls_id != selected_class:
                continue

            x1, y1, x2, y2 = map(int, box.xyxy[0])
            iou = compute_iou([x1, y1, x2, y2], selected_box)

            if iou > 0.1:
                label = f"{model.names[cls_id]} {box.conf[0]:.2f}"
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                # Update selected_box for next frame (track it)
                selected_box = [x1, y1, x2, y2]

    cv2.imshow("YOLOv8 Object Tracking (User-selected)", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 chair, 1 toilet, 131.9ms
# Speed: 2.5ms preprocess, 131.9ms inference, 46.3ms postprocess per image at shape (1, 3, 480, 640)
# Tracking class: person
#
# 0: 480x640 1 person, 118.7ms
# Speed: 4.9ms preprocess, 118.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 toilet, 135.1ms
# Speed: 2.0ms preprocess, 135.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 toilet, 124.3ms
# Speed: 2.2ms preprocess, 124.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 toilet, 119.9ms
# Speed: 2.1ms preprocess, 119.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.4ms
# Speed: 2.8ms preprocess, 118.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 115.3ms
# Speed: 1.9ms preprocess, 115.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 toilet, 117.5ms
# Speed: 2.6ms preprocess, 117.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Speed: 2.0ms preprocess, 119.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 toilet, 117.7ms
# Speed: 2.2ms preprocess, 117.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.4ms
# Speed: 2.3ms preprocess, 112.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 110.8ms
# Speed: 2.1ms preprocess, 110.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 114.4ms
# Speed: 2.2ms preprocess, 114.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.7ms
# Speed: 2.3ms preprocess, 112.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.9ms
# Speed: 3.2ms preprocess, 109.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.3ms
# Speed: 2.8ms preprocess, 113.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.3ms
# Speed: 2.0ms preprocess, 113.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.5ms
# Speed: 2.4ms preprocess, 117.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.3ms
# Speed: 2.6ms preprocess, 120.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.6ms
# Speed: 2.6ms preprocess, 113.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 141.0ms
# Speed: 2.7ms preprocess, 141.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.1ms
# Speed: 2.2ms preprocess, 110.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.5ms
# Speed: 1.9ms preprocess, 108.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.9ms
# Speed: 2.5ms preprocess, 106.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.4ms
# Speed: 2.3ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.7ms
# Speed: 2.9ms preprocess, 112.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.3ms
# Speed: 2.1ms preprocess, 117.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.1ms
# Speed: 2.2ms preprocess, 113.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.6ms
# Speed: 2.1ms preprocess, 113.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.3ms
# Speed: 2.7ms preprocess, 113.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.8ms
# Speed: 2.3ms preprocess, 109.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.6ms
# Speed: 2.6ms preprocess, 111.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.4ms
# Speed: 2.6ms preprocess, 111.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.8ms
# Speed: 2.0ms preprocess, 109.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 120.1ms
# Speed: 1.9ms preprocess, 120.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.7ms
# Speed: 3.8ms preprocess, 115.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.2ms
# Speed: 3.1ms preprocess, 109.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.0ms
# Speed: 2.2ms preprocess, 125.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 111.1ms
# Speed: 1.7ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 110.5ms
# Speed: 1.8ms preprocess, 110.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 113.7ms
# Speed: 2.1ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 120.7ms
# Speed: 2.4ms preprocess, 120.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 125.8ms
# Speed: 2.3ms preprocess, 125.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 116.3ms
# Speed: 2.4ms preprocess, 116.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 118.3ms
# Speed: 3.0ms preprocess, 118.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 112.6ms
# Speed: 1.9ms preprocess, 112.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 111.7ms
# Speed: 1.8ms preprocess, 111.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 123.4ms
# Speed: 1.9ms preprocess, 123.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 115.6ms
# Speed: 2.1ms preprocess, 115.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 116.4ms
# Speed: 2.6ms preprocess, 116.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 113.5ms
# Speed: 2.3ms preprocess, 113.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 118.3ms
# Speed: 2.2ms preprocess, 118.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 79
#      76     if cv2.waitKey(1) & 0xFF == ord('q'):
#      77         break
# ---> 79 cap.release()
#      80 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined
