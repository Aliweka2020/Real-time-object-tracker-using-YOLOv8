# %%
import cv2
from ultralytics import YOLO
import numpy as np

# Load YOLOv8 model
model = YOLO('yolov8n.pt')  # Fast version

# Open webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Cannot open webcam.")
    exit()

# Read first frame
ret, first_frame = cap.read()
if not ret:
    print("Error: Cannot read first frame.")
    exit()

# Let the user select an object to track
bbox = cv2.selectROI("Select Object", first_frame, fromCenter=False, showCrosshair=True)
cv2.destroyAllWindows()

(x, y, w, h) = map(int, bbox)
selected_box = [x, y, x + w, y + h]  # Convert to (x1, y1, x2, y2)

# Detect objects in the first frame to identify the selected object's class
initial_result = model.predict(source=first_frame, conf=0.3)[0]
selected_class = None

def compute_iou(boxA, boxB):
    # Compute intersection over union
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    interArea = max(0, xB - xA) * max(0, yB - yA)
    if interArea == 0:
        return 0.0

    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

# Find which detection matches the selected box (best IoU)
best_iou = 0
for box in initial_result.boxes:
    detected_box = box.xyxy[0].cpu().numpy().astype(int)
    iou = compute_iou(detected_box, selected_box)
    if iou > best_iou:
        best_iou = iou
        selected_class = int(box.cls[0])

if selected_class is None:
    print("Couldn't detect any object inside the selected box.")
    exit()

print(f"Tracking class: {model.names[selected_class]}")

# Start tracking loop
while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(source=frame, conf=0.3, stream=True)

    for result in results:
        for box in result.boxes:
            cls_id = int(box.cls[0])
            if cls_id != selected_class:
                continue

            x1, y1, x2, y2 = map(int, box.xyxy[0])
            iou = compute_iou([x1, y1, x2, y2], selected_box)

            if iou > 0.1:
                label = f"{model.names[cls_id]} {box.conf[0]:.2f}"
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                # Update selected_box for next frame (track it)
                selected_box = [x1, y1, x2, y2]

    cv2.imshow("YOLOv8 Object Tracking (User-selected)", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 cup, 162.0ms
# Speed: 2.5ms preprocess, 162.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Tracking class: cup
#
# 0: 480x640 1 person, 1 cup, 149.1ms
# Speed: 2.2ms preprocess, 149.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 166.4ms
# Speed: 3.1ms preprocess, 166.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 143.6ms
# Speed: 5.6ms preprocess, 143.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 142.2ms
# Speed: 2.5ms preprocess, 142.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 140.7ms
# Speed: 2.1ms preprocess, 140.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 136.3ms
# Speed: 2.6ms preprocess, 136.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 132.6ms
# Speed: 2.9ms preprocess, 132.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 127.7ms
# Speed: 2.4ms preprocess, 127.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 119.8ms
# Speed: 2.9ms preprocess, 119.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 178.7ms
# Speed: 2.6ms preprocess, 178.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.3ms
# Speed: 3.2ms preprocess, 122.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 123.3ms
# Speed: 2.6ms preprocess, 123.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 118.6ms
# Speed: 2.6ms preprocess, 118.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 123.3ms
# Speed: 3.1ms preprocess, 123.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 116.5ms
# Speed: 3.5ms preprocess, 116.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 113.4ms
# Speed: 2.3ms preprocess, 113.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 118.5ms
# Speed: 2.2ms preprocess, 118.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 123.0ms
# Speed: 3.2ms preprocess, 123.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 120.2ms
# Speed: 3.1ms preprocess, 120.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 123.8ms
# Speed: 2.4ms preprocess, 123.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 115.4ms
# Speed: 3.7ms preprocess, 115.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 116.3ms
# Speed: 2.5ms preprocess, 116.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 124.4ms
# Speed: 2.5ms preprocess, 124.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 115.2ms
# Speed: 2.6ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 122.3ms
# Speed: 3.0ms preprocess, 122.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 130.3ms
# Speed: 2.6ms preprocess, 130.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 121.1ms
# Speed: 1.6ms preprocess, 121.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 121.6ms
# Speed: 3.6ms preprocess, 121.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 128.3ms
# Speed: 3.3ms preprocess, 128.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 139.2ms
# Speed: 3.2ms preprocess, 139.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.0ms
# Speed: 2.8ms preprocess, 133.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 129